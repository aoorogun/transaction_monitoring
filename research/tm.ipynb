# %%
# %pwd
# Out:
# '/Users/aoamacsplace/Documents/DS_Projects/transaction_monitoring/research'

# %%
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# '/Users/aoamacsplace/Documents/DS_Projects/transaction_monitoring'

# %%
import pandas as pd
from transaction_monitoring.config.configuration import Configuration

# Load configuration
config = Configuration()

# Load the saved raw data
data_path = f"{config.data_ingestion.raw_data_dir}/raw_data.csv"

# Read and display the data
df = pd.read_csv(data_path)
df.head()  # Display first few rows
# Out:
# 2025-03-15 14:56:56,355 - INFO - 🔍 Attempting to load configuration from: config/config.yaml
# 2025-03-15 14:56:56,358 - INFO - ✅ Configuration loaded successfully.
# 2025-03-15 14:56:56,358 - INFO - 📂 Data Ingestion Config - Data Path: data/input.csv, Raw Data Dir: data/raw
#            ssn            cc_num      first      last  gender  \
# 0  305-46-8995  6533797437394335  Elizabeth    Rivera       0
# 1  106-82-9631  4514372317296618    Brandon  Carrillo       1
# 2  307-57-8285  4926911616466638      Cathy    Jordan       0
# 3  033-10-2894   213148280092057      David      Cruz       1
# 4  097-89-8606  3506323654018141      Dylan   Jackson       1
#
#                         street           city state    zip      lat  ...  \
# 0  44633 Gray Highway Apt. 612      Bradenton    FL  34210  27.4544  ...
# 1  79880 Hicks Summit Apt. 271       Appleton    WI  54913  44.3456  ...
# 2               829 Gordon Row         Tucson    AZ  85746  32.1422  ...
# ...
